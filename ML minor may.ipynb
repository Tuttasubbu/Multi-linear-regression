# %% [markdown]
#     --------------------- MACHINE LEARNING MAY MINOR PROJECT ---------------------------------

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# Shape of the given data
data.shape
# Out:
# (50, 5)

# %% [markdown]
#     * There are 5 features and 50 records

# %%
print('The 5 features are :')
for i in data.columns:
    print(i)
# Out:
# The 5 features are :
# R&D Spend
# Administration
# Marketing Spend
# State
# Profit

# %%
# Data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
#     We observed that, there are :
#         - Four numerical feature(s) which are in float type
#         - and One categorical feature which is in object type
#         - There are no null values in the data

# %%
# Categorical features in the data
cat_feat = data.select_dtypes(include='O')
for i in cat_feat.columns:
    print(i, '\n', data[i].value_counts(), '\n')
# Out:
# State
#  New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %% [markdown]
#     * The categorical feature 'state' contains three categories. They are ['New York', 'California', 'Florida']. And also there is no cardinality.

# %%
#Description of categorical features
cat_feat.describe()
# Out:
#            State
# count         50
# unique         3
# top     New York
# freq          17

# %%
# Numerical features in the data
num_feat = data.select_dtypes(include = 'number')
for i in num_feat.columns:
    print(i)
# Out:
# R&D Spend
# Administration
# Marketing Spend
# Profit

# %%
# Description of numerical features
num_feat.describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]).round(2)
# Out:
#        R&D Spend  Administration  Marketing Spend     Profit
# count      50.00           50.00            50.00      50.00
# mean    73721.62       121344.64        211025.10  112012.64
# std     45902.26        28017.80        122290.31   40306.18
# min         0.00        51283.14             0.00   14681.40
# 1%          0.00        51508.54             0.00   24967.48
# 5%        748.23        73613.30           856.77   45678.69
# 10%     14086.70        85013.77         34814.22   65172.90
# 25%     39936.37       103730.88        129300.13   90138.90
# 50%     73051.08       122699.80        212716.24  107978.19
# 75%    101602.80       144842.18        299469.08  139765.98
# 90%    135364.65       153540.04        363192.07  157910.80
# 95%    149360.41       155763.84        396803.83  187383.61
# 99%    164000.96       170419.26        458120.17  192031.64
# max    165349.20       182645.56        471784.10  192261.83

# %% [markdown]
#     We observed that,
#         - The average amount spent by startups for 'Research and Development' is 73721.62
#         - The average amount spent by startups for 'Administration' is 121344.64
#         - The average amount spent by startups for 'Marketing' is 112012.64
#         - Average profits are 112012.64
#         - Max amount is spent for marketing
#         - There is no outliers in the data

# %%
# Null values
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
#     - There is no null values in the data

# %%
# Duplicate records
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
#     - There is no Duplicated records in the data

# %%
# Outliers
# R&d Spend
sns.set_style('whitegrid')
sns.boxplot(x = 'R&D Spend', data=data)
plt.xlabel('Amount spent on Research and Development')
plt.show()

# %%
Q1 = data['R&D Spend'].quantile(0.25)
Q3 = data['R&D Spend'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - IQR*1.5
upper_limit = Q3 + IQR*1.5
print('Lower_limit = ', lower_limit)
print('Upper_limit = ', upper_limit)
# Out:
# Lower_limit =  -52563.275
# Upper_limit =  194102.445

# %% [markdown]
#     There is no ouliers in feature 'R&D sepnd'.

# %%
# Administration
sns.boxplot(x = 'Administration', data=data)
plt.xlabel('Amount spent on Administration')
plt.show()

# %%
Q1 = data['Administration'].quantile(0.25)
Q3 = data['Administration'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - IQR*1.5
upper_limit = Q3 + IQR*1.5
print('Lower_limit = ', lower_limit)
print('Upper_limit = ', upper_limit)
# Out:
# Lower_limit =  42063.91750000001
# Upper_limit =  206509.13749999998

# %% [markdown]
#     There is no ouliers in feature 'Administration'.

# %%
# Marketing Spend
sns.boxplot(x = 'Marketing Spend', data=data)
plt.xlabel('Amount spent on Marketing')
plt.show()

# %%
Q1 = data['Marketing Spend'].quantile(0.25)
Q3 = data['Marketing Spend'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - IQR*1.5
upper_limit = Q3 + IQR*1.5
print('Lower_limit = ', lower_limit)
print('Upper_limit = ', upper_limit)
# Out:
# Lower_limit =  -125953.29624999993
# Upper_limit =  554722.5137499999

# %% [markdown]
#     There is no ouliers in feature 'Marketing Spend'.

# %%
# Data Analysis

# %%
# Research & Development
sns.barplot(x = 'State', y = 'R&D Spend', data=data, ci=False)
plt.ylabel('Spends on Research and Development')
plt.show()

# %% [markdown]
#     - We can observe that the sepnds on Research and Development in california is less when compared to other two states.

# %%
sns.scatterplot(x = 'R&D Spend', hue='State', y = 'Profit', data=data)
plt.xlabel('Spends on Research and Development')
plt.show()

# %% [markdown]
#      - We can observe that profits are increased by increase in sepnds on Research & Development. Because Profits and Research & Development are positively corelated.

# %%
sns.histplot(x = 'R&D Spend', data=data, bins = 50, kde=True)
plt.xlabel('Spends on Research and Development')
plt.show()

# %% [markdown]
#     - We can observe that there is no skewness in the data

# %%
# Administration
sns.barplot(x = 'State', y = 'Administration', data=data, ci=False)
plt.ylabel('Spends on Administration')
plt.show()

# %% [markdown]
#     - We can observe that the sepnds on Administration in three states are in equal proportion

# %%
sns.scatterplot(x = 'Administration', hue='State', y = 'Profit', data=data)
plt.xlabel('Spends on Administration')
plt.show()

# %% [markdown]
#     - We observed that there is no corelation between Administration spends and Profit.

# %%
sns.histplot(x = 'Administration', data=data, bins = 50, kde=True)
plt.xlabel('Spends on Administration')
plt.show()

# %%
# Administration
sns.barplot(x = 'State', y = 'Marketing Spend', data=data, ci=False)
plt.ylabel('Spends on Marketing Spend')
plt.show()

# %% [markdown]
#     - We can observe that the spends on marketing in Florida is high when compared to other two states.

# %%
sns.scatterplot(x = 'Marketing Spend', hue='State', y = 'Profit', data=data)
plt.xlabel('Spends on Marketing Spend')
plt.show()

# %% [markdown]
#     We can observed that profit is increaed by increased in increase in the spends on marketing. Because Profit and Spends on marketing are positively corelated.

# %%
sns.histplot(x = 'Marketing Spend', data=data, bins = 50, kde=True)
plt.xlabel('Spends on Marketing')
plt.show()

# %% [markdown]
#     - We can observed that the data is slightly right skewed.

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, annot=True, fmt='g', mask=mask);

# %% [markdown]
#     - We can observe that Spends on Research & Development and Maketing are highly corelated with the profit.
#     - All independent varibles are having no corelation with each other.

# %%
# Encoding features
encoded_data = data.copy()
encoded_data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Dummy trap to create dummy variables for categorical features
s = pd.get_dummies(encoded_data['State'], drop_first=True)
s
# Out:
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# ...

# %%
# Concatenate dummy varaibles to the data 
encoded_data = pd.concat([encoded_data, s], axis=1)

# %%
encoded_data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  Florida  \
# 0  165349.20       136897.80        471784.10    New York  192261.83        0
# 1  162597.70       151377.59        443898.53  California  191792.06        0
# 2  153441.51       101145.55        407934.54     Florida  191050.39        1
# 3  144372.41       118671.85        383199.62    New York  182901.99        0
# 4  142107.34        91391.77        366168.42     Florida  166187.94        1
#
#    New York
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0

# %%
encoded_data.drop(labels=['State'], axis=1, inplace=True)

# %%
encoded_data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0  165349.20       136897.80        471784.10  192261.83        0         1
# 1  162597.70       151377.59        443898.53  191792.06        0         0
# 2  153441.51       101145.55        407934.54  191050.39        1         0
# 3  144372.41       118671.85        383199.62  182901.99        0         1
# 4  142107.34        91391.77        366168.42  166187.94        1         0

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(X)
scaled_features
# Out:
# array([[ 2.01641149e+00,  5.60752915e-01,  2.15394309e+00,
#         -6.85994341e-01,  1.39326109e+00],
#        [ 1.95586034e+00,  1.08280658e+00,  1.92360040e+00,
#         -6.85994341e-01, -7.17740563e-01],
#        [ 1.75436374e+00, -7.28257028e-01,  1.62652767e+00,
#          1.45773797e+00, -7.17740563e-01],
#        [ 1.55478369e+00, -9.63646307e-02,  1.42221024e+00,
#         -6.85994341e-01,  1.39326109e+00],
#        [ 1.50493720e+00, -1.07991935e+00,  1.28152771e+00,
#          1.45773797e+00, -7.17740563e-01],
#        [ 1.27980001e+00, -7.76239071e-01,  1.25421046e+00,
#         -6.85994341e-01,  1.39326109e+00],
#        [ 1.34006641e+00,  9.32147208e-01, -6.88149930e-01,
#         -6.85994341e-01, -7.17740563e-01],
#        [ 1.24505666e+00,  8.71980011e-01,  9.32185978e-01,
#          1.45773797e+00, -7.17740563e-01],
#        [ 1.03036886e+00,  9.86952101e-01,  8.30886909e-01,
#         -6.85994341e-01,  1.39326109e+00],
# ...

# %%
X = pd.DataFrame(data=scaled_features, columns=X.columns)

# %%
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend   Florida  New York
# 0   2.016411        0.560753         2.153943 -0.685994  1.393261
# 1   1.955860        1.082807         1.923600 -0.685994 -0.717741
# 2   1.754364       -0.728257         1.626528  1.457738 -0.717741
# 3   1.554784       -0.096365         1.422210 -0.685994  1.393261
# 4   1.504937       -1.079919         1.281528  1.457738 -0.717741

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
# Splitting data into Training and Testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Creating model
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predictions
predictions = reg.predict(X_test)
predictions
# Out:
# array([126464.76354539,  85538.22928108,  99367.07880812,  45864.36860436,
#        128321.87763051,  51947.22582106, 108901.08466238, 100508.67082733,
#         97668.72028982, 112423.71311462, 128907.87800423, 174736.83458726,
#         93516.90479145])

# %% [markdown]
#     - The above values are the prediction of profit in Test data

# %%
# Model evaluation
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score,mean_squared_error, mean_squared_log_error, mean_absolute_error

mae = mean_absolute_error(y_test, predictions) # Lower the values better the model (0 to infinity)
print('Mean Absolute Error :', mae)

accuracy =  r2_score(y_test, predictions).round(4) # Higher the value better the model (0 to 1)
print('R Squared :', accuracy)

mse = mean_squared_error(y_test, predictions) # Lower the value better the model(0 to infinity)
print('Mean Squared Error :', mse)

mse_log_error = mean_squared_log_error(y_test, predictions) # Lower the value better the model (0 to infinty)
print('Mean Squared Log Error :', mse_log_error)
# Out:
# Mean Absolute Error : 7437.24185842277
# R Squared : 0.9191
# Mean Squared Error : 86972050.78605832
# Mean Squared Log Error : 0.022696762642297193

# %%
reg.coef_ # M(slope) value(s)
# Out:
# array([36842.69327435, -2494.1360932 ,  3624.77046766,   128.44517818,
#         -159.77131271])

# %%
reg.intercept_ # intercept (C) value(s)
# Out:
# 111650.27139935238

# %%
# Cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
reg = LinearRegression()
k_fold = KFold(n_splits=10, shuffle=True, random_state=1)
cross_validation_score = cross_val_score(reg, X_train, y_train, scoring='r2', cv = k_fold)
print(cross_validation_score)
# Out:
# [0.98717594 0.77444106 0.66199319 0.73219418 0.81631779 0.96593562
#  0.90061535 0.71190429 0.98974635 0.95329115]

# %%
print('Cross validation score : ', cross_validation_score.mean())
# Out:
# Cross validation score :  0.8493614926413041
